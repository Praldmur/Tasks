# %%
import clickhouse_connect as cc
import pandas as pd

# %%
connection = dict(database = 'medteh',
                  host = 'https://datalake.emias.ru:8888',
                  user = 'Tarasov.AV1',
                  password = 'aXdsE6M-6Ffy')
